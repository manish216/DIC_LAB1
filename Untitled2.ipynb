# %%
library(rtweet)
library(data.table)

# %%
create_token(" Influenza_Data_Global","9X8jlNc1yogKgV3kwplS0RmW7","ldulElQPi9ZKQO9Lmn6Yk8WdGkwtVnbaJMZ2jYAH5ReaOWpVfd","252359090-tHiCXx0H7IBDZ72AHAoOam9R9Gi9oOlh2zwKf8zq","X0Ew37O2U0D2OjScM1r5AN9McHgLwd3ETOmN80GCwTzya")
# Out:
# <Token>
# <oauth_endpoint>
#  request:   https://api.twitter.com/oauth/request_token
#  authorize: https://api.twitter.com/oauth/authenticate
#  access:    https://api.twitter.com/oauth/access_token
# <oauth_app>  Influenza_Data_Global
#   key:    9X8jlNc1yogKgV3kwplS0RmW7
#   secret: <hidden>
# <credentials> oauth_token, oauth_token_secret
# ---

# %%
#rt <- lat_lng(twee)
#maps::map("state", lwd = .25)
#### plot lat and lng points onto state map
#with(rt, points(lng, lat, pch = 20, cex = .75, col = rgb(0, .3, .7, .75)))

# %%
twee1 = search_tweets(q="#flu OR #influenza",n =50,lang="en",include_rts =FALSE, geocode = lookup_coords("usa"))
# Out:
# Searching for tweets...
# Error in curl::curl_fetch_memory(url, handle = handle): Could not resolve host: api.twitter.com
# Traceback:
#
# 1. search_tweets(q = "#flu OR #influenza", n = 50, lang = "en",
#  .     include_rts = FALSE, geocode = lookup_coords("usa"))
# 2. do.call("search_tweets_", args)
# 3. search_tweets_(q = "#flu OR #influenza", n = 50, type = "recent",
#  .     include_rts = FALSE, geocode = structure(list(place = "usa",
#  .         box = c(sw.lng = -124.848974, sw.lat = 24.396308, ne.lng = -66.885444,
#  .         ne.lat = 49.384358), point = c(lat = 36.89, lng = -95.867
#  .         )), class = c("coords", "list")), max_id = NULL, parse = TRUE,
#  .     token = NULL, retryonratelimit = FALSE, verbose = TRUE, lang = "en")
# 4. .search_tweets(q = q, n = n, type = type, geocode = geocode,
#  .     max_id = max_id, include_rts = include_rts, parse = parse,
#  .     token = token, verbose = verbose, ...)
# 5. scroller(url, n, n.times, type = "search", token)
# ...

# %%
fwrite(final, file ="myDT.csv")
# Out:
# Error in fwrite(final, file = "myDT.csv"): object 'final' not found
# Traceback:
#
# 1. fwrite(final, file = "myDT.csv")

# %%
Data <- read.csv("myDT.csv")

# %%
Data
# Out:
#      user_id      status_id   created_at           screen_name
# 1    424664120    1.10047e+18 2019-02-26T18:53:32Z ViraBurnayeva
# 2    424664120    1.09940e+18 2019-02-23T20:05:42Z ViraBurnayeva
# 3    424664120    1.09741e+18 2019-02-18T08:07:50Z ViraBurnayeva
# 4    424664120    1.09819e+18 2019-02-20T12:14:24Z ViraBurnayeva
# 5    424664120    1.09975e+18 2019-02-24T19:22:13Z ViraBurnayeva
# 6    424664120    1.09950e+18 2019-02-24T02:43:33Z ViraBurnayeva
# 7    424664120    1.10046e+18 2019-02-26T18:25:28Z ViraBurnayeva
# 8    424664120    1.10023e+18 2019-02-26T03:23:21Z ViraBurnayeva
# 9    424664120    1.09861e+18 2019-02-21T16:03:07Z ViraBurnayeva
# 10   424664120    1.09734e+18 2019-02-18T03:23:17Z ViraBurnayeva
# 11   424664120    1.09918e+18 2019-02-23T05:16:05Z ViraBurnayeva
# 12   424664120    1.09953e+18 2019-02-24T04:35:43Z ViraBurnayeva
# 13   424664120    1.09998e+18 2019-02-25T10:19:39Z ViraBurnayeva
# ...

# %%
rt <-lat_lng(Data)

# %%
rt
# Out:
#      user_id      status_id   created_at           screen_name
# 1    424664120    1.10047e+18 2019-02-26T18:53:32Z ViraBurnayeva
# 2    424664120    1.09940e+18 2019-02-23T20:05:42Z ViraBurnayeva
# 3    424664120    1.09741e+18 2019-02-18T08:07:50Z ViraBurnayeva
# 4    424664120    1.09819e+18 2019-02-20T12:14:24Z ViraBurnayeva
# 5    424664120    1.09975e+18 2019-02-24T19:22:13Z ViraBurnayeva
# 6    424664120    1.09950e+18 2019-02-24T02:43:33Z ViraBurnayeva
# 7    424664120    1.10046e+18 2019-02-26T18:25:28Z ViraBurnayeva
# 8    424664120    1.10023e+18 2019-02-26T03:23:21Z ViraBurnayeva
# 9    424664120    1.09861e+18 2019-02-21T16:03:07Z ViraBurnayeva
# 10   424664120    1.09734e+18 2019-02-18T03:23:17Z ViraBurnayeva
# 11   424664120    1.09918e+18 2019-02-23T05:16:05Z ViraBurnayeva
# 12   424664120    1.09953e+18 2019-02-24T04:35:43Z ViraBurnayeva
# 13   424664120    1.09998e+18 2019-02-25T10:19:39Z ViraBurnayeva
# ...

# %%
Data$location
# Out:
#    [1] Arlington, VA                  Arlington, VA
#    [3] Honey Brook, PA                Collinsville, IL
#    [5] Missouri, USA                  Upstate NY
#    [7] Thunder Bay, Ontario, Canada   Leawood, KS
#    [9] Newtown Square, Pa.            Cleveland, OH
#   [11] Pittsburgh, Baltimore, NYC     Ann Arbor
#   [13] Ann Arbor                      Thorofare, NJ
#   [15] Blue Ash, OH                   Phoenix, AZ
#   [17] Tennessee, USA                 California, USA
#   [19] Baton Rouge, LA                Minneapolis, MN
#   [21] Minneapolis, MN                Atlanta, GA
#   [23] Atlanta, GA                    Florida
#   [25] Canada                         Madison, WI
#   [27] Boston, MA                     Boston, MA
#   [29] United States                  Fairfax County, Virginia
#   [31] Irvine, CA                     Boston, MA
#   [33] Clearwater, FL                 Dallas, Texas
#   [35] Durham, NC                     Durham, NC
# ...

# %% [markdown]
# ##### =============================================================

# %%
Location_data <- Data

# %%
Location_data.location <- as.character(Location_data$location)
Location_data.location
# Out:
#    [1] "Arlington, VA"                  "Arlington, VA"
#    [3] "Honey Brook, PA"                "Collinsville, IL"
#    [5] "Missouri, USA"                  "Upstate NY"
#    [7] "Thunder Bay, Ontario, Canada"   "Leawood, KS"
#    [9] "Newtown Square, Pa."            "Cleveland, OH"
#   [11] "Pittsburgh, Baltimore, NYC"     "Ann Arbor"
#   [13] "Ann Arbor"                      "Thorofare, NJ"
#   [15] "Blue Ash, OH"                   "Phoenix, AZ"
#   [17] "Tennessee, USA"                 "California, USA"
#   [19] "Baton Rouge, LA"                "Minneapolis, MN"
#   [21] "Minneapolis, MN"                "Atlanta, GA"
#   [23] "Atlanta, GA"                    "Florida"
#   [25] "Canada"                         "Madison, WI"
#   [27] "Boston, MA"                     "Boston, MA"
#   [29] "United States"                  "Fairfax County, Virginia"
#   [31] "Irvine, CA"                     "Boston, MA"
#   [33] "Clearwater, FL"                 "Dallas, Texas"
# ...

# %%
Location_data = separate(data = Location_data, col = location, into = c("left", "right"), sep = (","|" "))
Location_data.left <- as.list(Location_data$left)
# Out:
# Error in separate(data = Location_data, col = location, into = c("left", : could not find function "separate"
# Traceback:

# %%
Location.left <-table(Location_data$left)

# %%
Location_temp <-as.data.frame(Location.left)

# %%
Location_temp$Var1 <- as.character(tolower(Location_temp$Var1))
fwrite(Location_temp, file ="myDTL.csv")

# %%
library(dplyr)
library(tidyr)
library(ggplot2)
library(mapdata)
m <- (urbnmapr::states)
colnames(m)[which(names(m) == "state_name")] <- "state"
colnames(Location_temp)[which(names(Location_temp)=="Var1")] <-"state"
m$state <- as.character(m$state)
m$state <- tolower(m$state)

ab1 <- merge(x=m, y=Location_temp, by.x=c("state"), by.y=c("state"), all.x=TRUE)
ab1.freq <- Location_temp$Freq
na.omit(ab1)
# Out:
#       state   long      lat      order hole  piece group state_fips state_abbv
# 1     alabama -88.41956 30.87519 730   FALSE 1     01.1  01         AL
# 2     alabama -88.42564 30.99830 731   FALSE 1     01.1  01         AL
# 3     alabama -87.92003 30.47065 651   FALSE 1     01.1  01         AL
# 4     alabama -87.62079 30.88746 429   FALSE 1     01.1  01         AL
# 5     alabama -87.92421 30.47610 652   FALSE 1     01.1  01         AL
# 6     alabama -87.91114 30.52585 655   FALSE 1     01.1  01         AL
# 7     alabama -87.91414 30.44614 650   FALSE 1     01.1  01         AL
# 8     alabama -87.93190 30.48110 653   FALSE 1     01.1  01         AL
# 9     alabama -87.91935 30.63606 663   FALSE 1     01.1  01         AL
# 10    alabama -88.47111 31.85095 753   FALSE 1     01.1  01         AL
# 11    alabama -88.42573 31.00018 732   FALSE 1     01.1  01         AL
# 12    alabama -87.90171 30.55088 657   FALSE 1     01.1  01         AL
# ...

# %%
abb2<-(abb1[1:5000,])
abb2
# Out:
#      state   long      lat      Freq
# 3    alabama -88.41956 30.87519 2
# 4    alabama -88.42564 30.99830 2
# 5    alabama -87.92003 30.47065 2
# 6    alabama -87.62079 30.88746 2
# 7    alabama -87.92421 30.47610 2
# 8    alabama -87.91114 30.52585 2
# 9    alabama -87.91414 30.44614 2
# 10   alabama -87.93190 30.48110 2
# 11   alabama -87.91935 30.63606 2
# 12   alabama -88.47111 31.85095 2
# 13   alabama -88.42573 31.00018 2
# 14   alabama -87.90171 30.55088 2
# 15   alabama -87.93336 30.48736 2
# 16   alabama -88.26164 30.24469 2
# 17   alabama -87.93107 30.65269 2
# 18   alabama -88.30433 30.23766 2
# 19   alabama -87.90891 30.41424 2
# 20   alabama -88.14373 30.26049 2
# 21   alabama -88.22555 30.25083 2
# 22   alabama -88.17778 30.25786 2
# 23   alabama -88.28857 30.23854 2
# 24   alabama -88.04374 30.51742 2
# 25   alabama -88.07485 30.24912 2
# 26   alabama -88.07586 30.24614 2
# 27   alabama -88.15897 30.25786 2
# 28   alabama -88.09290 30.24073 2
# ...

# %%
m <- map_data("usa") 
colnames(m)[which(names(m) == "region")] <- "state"
m$state <- as.character(m$state)
m$state <- tolower(m$state)
ab2 <- merge(x=Location_temp, y=m, by.x=c("Var1"), by.y=c("Var1"), all.x=TRUE)
ab2
# Out:
#     Var1                   Freq long lat group order subregion
# 1                           4   NA   NA  NA    NA    NA
# 2   achille                 1   NA   NA  NA    NA    NA
# 3   alabama                 2   NA   NA  NA    NA    NA
# 4   alaska                  1   NA   NA  NA    NA    NA
# 5   albany                  2   NA   NA  NA    NA    NA
# 6   alberta                 1   NA   NA  NA    NA    NA
# 7   albuquerque             2   NA   NA  NA    NA    NA
# 8   alexandria              4   NA   NA  NA    NA    NA
# 9   allentown               1   NA   NA  NA    NA    NA
# 10  ambler                  1   NA   NA  NA    NA    NA
# 11  ann arbor               6   NA   NA  NA    NA    NA
# 12  annapolis               1   NA   NA  NA    NA    NA
# 13  antioch                 1   NA   NA  NA    NA    NA
# 14  ãœt: 44.921604          2   NA   NA  NA    NA    NA
# 15  appleton                1   NA   NA  NA    NA    NA
# 16  arizona                 2   NA   NA  NA    NA    NA
# ...

# %%
abb <- na.omit(ab1)
abb1 <- subset(abb, select=c("state","Freq"))
sapply(abb1,class)
abb2<-sample_n(abb1, 1000)
# Out:
#       state        Freq
# "character"   "integer"

# %%
gc(reset =TRUE)
# Out:
#        used     (Mb)  gc trigger (Mb)   max used (Mb)
# Ncells   857643  26.2   2884198    88.1   857643  26.2
# Vcells 61580227 469.9 194804984  1486.3 61580227 469.9

# %%
library(usmap)
library(ggplot2)
plot_usmap(data = abb2, values = "Freq", lines = "black") + 
  scale_fill_continuous(
    low = "green", high = "red", name = "Population (2015)", label = scales::comma
  ) + theme(legend.position = "right")
# Out:
# plot without title

# %%
plt6
# Out:
# plot without title

# %% [markdown]
# #### =======================================================

# %%
library("ggmap")
library("maptools")
library("maps")
register_google(key = 'AIzaSyDM1ib8qKXgyhEICFTH2wIB5v8LU6udxhc') # giving the google secret API key  
Loc <- geocode(Location_data)
Loc.x <- Loc$lon
Loc.y <- Loc$lat
# Out:
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=arlington,+va&key=xxx
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=arlington,+va&key=xxx
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=honey+brook,+pa&key=xxx
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=collinsville,+il&key=xxx
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=missouri,+usa&key=xxx
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=upstate+ny&key=xxx
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=thunder+bay,+ontario,+canada&key=xxx
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=leawood,+ks&key=xxx
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=newtown+square,+pa.&key=xxx
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=cleveland,+oh&key=xxx
# ...

# %%
Loc
# Out:
# Error in eval(expr, envir, enclos): object 'Loc' not found
# Traceback:

# %%
Loc_f <- cbind(Location_data,Loc)
Loc_f$Location_data <- as.character(Loc_f$Location_data)

# %%
sapply(Loc_f,class)
Loc_f
# Out:
# Location_data           lon           lat
#   "character"     "numeric"     "numeric"
#      Location_data                lon        lat
# 1    arlington, va                 -77.09098 38.88162
# 2    arlington, va                 -77.09098 38.88162
# 3    honey brook, pa               -75.91133 40.09427
# 4    collinsville, il              -89.98455 38.67033
# 5    missouri, usa                 -91.83183 37.96425
# 6    upstate ny                    -76.04885 43.04820
# 7    thunder bay, ontario, canada  -89.24768 48.38090
# 8    leawood, ks                   -94.61690 38.96667
# 9    newtown square, pa.           -75.40071 39.98689
# 10   cleveland, oh                 -81.69436 41.49932
# 11   pittsburgh, baltimore, nyc    -74.00597 40.71278
# 12   ann arbor                     -83.74304 42.28083
# 13   ann arbor                     -83.74304 42.28083
# 14   thorofare, nj                 -75.19693 39.84221
# 15   blue ash, oh                  -84.37827 39.23200
# ...

# %%
library(stringr)
Loc_f1 <- str_split_fixed(Loc_f$Location_data, ",", 2)
colnames(Loc_f1) <- c("region","code")
Loc_f2 <- cbind(Loc_f1,Loc_f)
Loc_f2
# Out:
#      region                       code             Location_data
# 1    arlington                     va              arlington, va
# 2    arlington                     va              arlington, va
# 3    honey brook                   pa              honey brook, pa
# 4    collinsville                  il              collinsville, il
# 5    missouri                      usa             missouri, usa
# 6    upstate ny                                    upstate ny
# 7    thunder bay                   ontario, canada thunder bay, ontario, canada
# 8    leawood                       ks              leawood, ks
# 9    newtown square                pa.             newtown square, pa.
# 10   cleveland                     oh              cleveland, oh
# 11   pittsburgh                    baltimore, nyc  pittsburgh, baltimore, nyc
# 12   ann arbor                                     ann arbor
# 13   ann arbor                                     ann arbor
# ...

# %%
library(plyr)
Y <- count(Loc_f1, 'Location_data')

# %%
Y
# Out:
#     Location_data                 freq
# 1                                  4
# 2   achille, ok                    1
# 3   alabama, usa                   2
# 4   alaska, usa                    1
# 5   albany, ga                     1
# 6   albany, new york               1
# 7   alberta                        1
# 8   albuquerque, nm usa            2
# 9   alexandria, va                 3
# 10  alexandria, virginia           1
# 11  allentown, pa                  1
# 12  ambler, pa                     1
# 13  ann arbor                      4
# 14  ann arbor, mi                  2
# 15  annapolis, md                  1
# 16  antioch, il                    1
# 17  ãœt: 44.921604,-93.232332      2
# 18  appleton, wi                   1
# 19  arizona and indiana            1
# 20  arizona, usa                   2
# 21  arkansas, usa                  2
# 22  arlington, va                 28
# 23  around the corner              1
# 24  asheville, nc                  2
# ...

# %%
ab1 <- merge(x=Loc_temp, y=m, by.x=c("V1"), by.y=c("V1"), all.x=TRUE)

# %%
ab1
# Out:
# Error in eval(expr, envir, enclos): object 'ab1' not found
# Traceback:

# %%
library(dplyr)
library(tidyr)
library(ggplot2)
library(mapdata)
m <- (urbnmapr::states)
colnames(m)[which(names(m) == "state_name")] <- "V1"
m$V1 <- as.character(m$V1)
m$V1 <- tolower(m$V1)
head(m)
# Out:
#   long      lat      order hole  piece group state_fips state_abbv V1
# 1 -88.47323 31.89386 1     FALSE 1     01.1  01         AL         alabama
# 2 -88.46888 31.93026 2     FALSE 1     01.1  01         AL         alabama
# 3 -88.46866 31.93317 3     FALSE 1     01.1  01         AL         alabama
# 4 -88.45504 32.03972 4     FALSE 1     01.1  01         AL         alabama
# 5 -88.45496 32.04058 5     FALSE 1     01.1  01         AL         alabama
# 6 -88.45342 32.05305 6     FALSE 1     01.1  01         AL         alabama

# %%
ab1 <- merge(x=Loc_f, y=m, by.x=c("state_name"), by.y=c("Location_data"), all.x=TRUE)
# Out:
# Error in fix.by(by.x, x): 'by' must specify a uniquely valid column
# Traceback:
#
# 1. merge(x = Loc_f, y = m, by.x = c("state_name"), by.y = c("Location_data"),
#  .     all.x = TRUE)
# 2. merge(x = Loc_f, y = m, by.x = c("state_name"), by.y = c("Location_data"),
#  .     all.x = TRUE)
# 3. merge.data.frame(x = Loc_f, y = m, by.x = c("state_name"), by.y = c("Location_data"),
#  .     all.x = TRUE)
# 4. fix.by(by.x, x)
# 5. stop(ngettext(sum(bad), "'by' must specify a uniquely valid column",
#  .     "'by' must specify uniquely valid columns"), domain = NA)

# %%
ab1
# Out:
#        V1      V2   long      lat      order hole  piece group state_fips
# 1                          NA       NA  NA      NA NA    NA    NA
# 2                          NA       NA  NA      NA NA    NA    NA
# 3                          NA       NA  NA      NA NA    NA    NA
# 4                          NA       NA  NA      NA NA    NA    NA
# 5      achille  ok         NA       NA  NA      NA NA    NA    NA
# 6      alabama  usa -88.27321 30.33329 787   FALSE 3     01.3  01
# 7      alabama  usa -88.26727 30.35381 781   FALSE 3     01.3  01
# 8      alabama  usa -87.39732 30.60871 514   FALSE 1     01.1  01
# 9      alabama  usa -87.39928 30.60560 515   FALSE 1     01.1  01
# 10     alabama  usa -87.39504 30.61527 513   FALSE 1     01.1  01
# 11     alabama  usa -87.40657 30.59991 518   FALSE 1     01.1  01
# 12     alabama  usa -87.40875 30.58369 519   FALSE 1     01.1  01
# 13     alabama  usa -87.40461 30.60337 517   FALSE 1     01.1  01
# ...
